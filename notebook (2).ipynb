# %% [markdown]
# <div style="border:solid Green 2px; border-radius: 10px;  padding: 40px">
# <b>Привет, Виталий!👋</b>
#
# Меня зовут Зуева Юлия, можно просто Юля 😏 Я буду ревьюером твоего проекта. Предлагаю обращаться на "ты", но если это неудобно, пожалуйста, скажи об этом!
#
# Моя основная цель - помочь тебе стать компетентным Data Scientist'ом: вместе преодолеть трудности и еще больше развить твои сильные навыки 💪 В твоей работе я оставила комментарии, которые должны в этом помочь. Для твоего удобства комментарии раскрашены разными цветами:
# <br/>
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> В случае корректного решения (или отдельных его моментов). На такие решения можно опираться в будущем.
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b> Если есть возможность как-либо улучшить решение. Ты можешь учесть эти комментарии при доработке проекта, однако для зачета это не обязательно.
# </div>
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
# <b>Нужно доработать ❌:</b> Если решение требует внесения правок. Проект не может быть принят, если остались не отработанные комментарии данного типа.
# </div>
#
# Чтобы наша с тобой работа была еще эффективнее, ты точно так же можешь оставлять комментарии и задавать мне вопросы. Для таких случаев, пожалуйста, выбери собственное оформление комментариев, которое будет отличаться от моего, чтобы не создавалась путаница. По этой же причине попрошу тебя не удалять и не изменять мои комментарии. Все это позволит лучше ориентироваться в нашем с тобой диалоге, а повторную проверку (в случае ее необходимости) выполнять оперативнее 🚀
#
# Не спеши расстраиваться, если что-то не удалось с первого раза. Вместе мы обязательно разберемся со всеми трудностями! 🤓

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши с помощью Python
#
# - Автор: Лопатин Виталий
# - Дата: 18.01.2026

# %% [markdown]
# ### Цели и задачи проекта
#
# <font color='#777778'>Проанализировать поведение пользователей. Провести исследовательский анализ данных, чтобы понять, какие пользователи с большей вероятностью возвращаются на платформу и делают заказы повторно.
# </font>

# %% [markdown]
# ### Описание данных:
#
# - user_id — уникальный идентификатор пользователя, совершившего заказ;
# - device_type_canonical — тип устройства, с которого был оформлен заказ ( mobile — мобильные устройства, desktop — стационарные);
# - order_id — уникальный идентификатор заказа;
# - order_dt — дата создания заказа (используйте данные created_dt_msk );
# - order_ts — дата и время создания заказа (используйте данные created_ts_msk );
# - currency_code — валюта оплаты;
# - revenue — выручка от заказа;
# - tickets_count — количество купленных билетов;
# - days_since_prev — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - event_id — уникальный идентификатор мероприятия;
# - service_name — название билетного оператора;
# - event_type_main — основной тип мероприятия (театральная постановка, концерт и так далее);
# - region_name — название региона, в котором прошло мероприятие;
# - city_name — название города, в котором прошло мероприятие.

# %% [markdown]
# ### Содержание проекта:
# 1. **Загрузка данных и их предобработка**
#
# 1.1. Выгрузка данных из базы данных с помощью SQL
# 1.2. Первичный анализ данных и оценка корректности выгрузки
#
# 2. **Предобработка данных**
#
# 2.1. Приведение выручки к единой валюте
# 2.2. Обработка пропущенных значений и преобразование типов данных
# 2.3. Анализ категориальных признаков
# 2.4. Анализ распределений и обработка выбросов
# 2.5. Промежуточные выводы по результатам предобработки
#
# 3. **Создание профиля пользователя**
#
# 3.1. Формирование агрегированных признаков пользователя
# 3.2. Первичный анализ профилей пользователей
#
# 4. **Исследовательский анализ данных**
# 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# 4.1.1. Распределение пользователей по признакам первого заказа
# 4.1.2. Анализ возвратов пользователей в разрезе сегментов
# 4.1.3. Проверка продуктовых гипотез
#
# 4.2. **Исследование поведения пользователей через показатели выручки и состава заказа**
#
# 4.2.1. Связь средней выручки с заказа с повторными покупками
# 4.2.2. Сравнение средней выручки с заказа у разных групп пользователей
# 4.2.3. Влияние среднего количества билетов в заказе на повторные покупки
#
# 4.3. **Исследование временных характеристик первого заказа**
#
# 4.3.1. Влияние дня недели первой покупки на возврат пользователей
# 4.3.2. Влияние среднего интервала между заказами на удержание клиентов
#
# 4.4. **Корреляционный анализ количества покупок и признаков пользователя**
#
# 4.4.1. Анализ корреляции между признаками профиля пользователя и числом заказов
#
# 5. **Общие выводы и рекомендации**

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Вводная часть <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Здорово, что оставляешь вводную часть! Она помогает быстро понять цель, контекст и структуру работы, что будет удобно не только для тебя при возвращении к проекту спустя время, но и любому другому читателю (если, например, публикуешь в открытый доступ для портфолио). Воспринимаем эту тетрадку не просто как выполнение домашней работы на курсе, а как полноценный исследовательский проект.
#
# Как правило, во вводную часть включают название проекта, краткое описание цели, используемых данных (источники, объем, особенности), нюансы самого проекта (специфические условия, ограничения, предположения и т.д.). Иногда также сразу обозначают план шагов. Другими словами, вводная часть призвана отразить, что мы делаем, с чем работаем и на каких условиях.
# </div>

# %% [markdown]
# ### 1. Загрузка данных и их предобработка

# %% [markdown]
# #### 1.1:Выгрузка SQL запроса в датафрейм pandas

# %%
# импорт библиотек:
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import numpy as np
from joblib import parallel_backend
import re
import  phik

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Импорты <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Все необходимые библиотеки лучше подгружаешь сразу в начале проекта, это соответствует стандартам оформления кода <a href='https://pyplanet.ru/article/pep-0008.html'>PEP 8</a>. Такой подход позволяет сразу видеть, какое окружение необходимо для запуска проекта, избежать дублирования импортов в разных частях кода, а также облегчить отладку и переносимость проекта.
#
#
# * Хорошей практикой также является упорядочивание импортов. PEP 8 рекомендует сначала подгружать стандартные python-библиотеки, затем сторонние. Но для удобства каждую их этих групп также можно структурировать по тематике. Например, библиотеки для работы с данными, для работы с графиками и т.д. Тогда будет удобнее поддерживать порядок в импортах от проекта к проекту, не подгружать лишнее.
#
# </div>

# %%
import os
from dotenv import load_dotenv 
    
load_dotenv( r'C:\Users\Виталий\Project_Yandex\.env.txt') # автоматически ищет .env в текущей директории
    
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    os.getenv('DB_USER'),
    os.getenv('DB_PASSWORD'),
    os.getenv('DB_HOST'),
    os.getenv('DB_PORT'),
    os.getenv('DB_NAME'),
)

# %%
engine = create_engine(connection_string) # подключение к базе данных

# %%
# SQL запрос необходимых данных
query = '''
 SELECT 
    p.user_id,
    p.device_type_canonical,
    p.order_id,
    p.created_dt_msk AS order_dt,
    p.created_ts_msk AS order_ts,
    p.currency_code,
    p.revenue,
    p.tickets_count,
    
  
    EXTRACT(DAY FROM (
        p.created_dt_msk - 
        LAG(p.created_dt_msk) OVER (
            PARTITION BY p.user_id
            ORDER BY p.created_dt_msk
        )
    ))::INTEGER AS days_since_prev,
    
    p.event_id,
    e.event_name_code AS event_name,
    e.event_type_main,
    p.service_name,
    r.region_name,
    c.city_name

FROM afisha.purchases p
INNER JOIN afisha.events e ON p.event_id = e.event_id
LEFT JOIN afisha.city c ON e.city_id = c.city_id
LEFT JOIN afisha.regions r ON c.region_id = r.region_id

WHERE 
    p.device_type_canonical IN ('mobile', 'desktop')
    AND e.event_type_main != 'фильм'

ORDER BY 
    p.user_id ASC
'''

# %%
df = pd.read_sql_query(query, con=engine) # Преобразование SQL выборки в датафрейм

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Загрузка данных <a class="tocSkip"></h4>
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Выгрузка данных проведена корректно! Была выполнена необходимая фильтрация данных, выгружены только необходимые для анализа данные. Отлично, что сразу подсчитываешь время между заказами для каждого пользователя.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> Сейчас ты явным образом прописываешь параметры подключения к БД. В таком виде выкладывать работу в публичный доступ небезопасно, кто-то сможет завладеть подключением, украсть или повредить данные. Лучше сразу в процессе работы держать чувствительные значения отдельно от основного содержания, иначе есть высокий риск забыть об этом нюансе.
#
# Чтобы засекретить подключение, необходимо сложить все параметры в `.env` файл (или другой конфигурационный файл вне Git) и указать его в `.gitignore`:
#
# ```python
# DB_NAME="..."
# DB_HOST="..."
# DB_PORT="..."
# DB_USER="..."
# DB_PASSWORD="..."
# ```
#
# В самом проекте мы можем обращаться к сохраненным параметрам, для этого нам потребуются библиотеки `dotenv`, чтобы загрузить переменные окружения, и `os`, чтобы обратиться к ним:
#
# ```python
# import os
# import dotenv
#
# load_dotenv() # автоматически ищет .env в текущей директории
#
# connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
#     os.getenv('DB_USER'),
#     os.getenv('DB_PASSWORD'),
#     os.getenv('DB_HOST'),
#     os.getenv('DB_PORT'),
#     os.getenv('DB_NAME'),
# )
# ```
#
# Также данный файл можно добавить в репозиторий и здесь на платформе. Для этого нужно нажать на лого jupyter hub, найти кнопку для создания нового файла, внести необходимое содержимое, переименовать файл нужным образом и сохранить.
#
# </div>

# %%
display(df.head()) # Вызов первых пяти строк датафрейма
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name event_type_main  \
# ...

# %%
print("Общая информация о датасете:")
print(df.info())
print("\nОписание числовых признаков:")
print(df.describe())
# Out:
# Общая информация о датасете:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
# ...

# %% [markdown]
# #### 1.2: Общая информацию о выгруженных данных.

# %% [markdown]
# ### Промежуточные выводы:
# **Объем данных:**
# В наборе данных содержится 290611 записей
# Представлено 15 столбцов с различными характеристиками
#
# **Структура данных**
# Типы данных корректны:
# Числовые типы (int64, float64) используются для числовых значений (order_id, revenue, tickets_count)
# Строковые данные (object) корректно применены к текстовым полям (user_id, device_type_canonical)
# Временные метки (datetime64) правильно определены для order_dt и order_ts
#
# **Пропуски данных**
# Обнаружены пропуски только в одном поле:
# В столбце days_since_prev отсутствует 21933 значения (примерно 7.5% от общего объема)
#
# **Особенности данных**
# Уникальные идентификаторы:
# user_id содержит уникальные значения
# event_id представлен в числовом формате
# event_name содержит UUID-подобные значения
# revenue имеет отрицательные значения, что указывает на наличие ошибочных значений
#
# **Типы событий:**
# Встречаются различные категории мероприятий: театр, выставки, стендап, другое
# Разные сервисы бронирования билетов

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Проверка корректности загруженных данных <a class="tocSkip"></h4>
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b>
#
# * Хорошо, что убеждаешь в корректности данных! Если при подгрузке возникли проблемы, а мы их не обнаружим, все последующие расчеты могут быть искажены.
#
#
# * Круто, что не забываешь зафиксировать промежуточные наблюдения в выводах! Если потребуется вернуться к проекту спустя время, будет проще освежить в памяти все ключевые этапы работы, что и почему мы делали, что получили.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * `print` используется для простого текстового вывода. Но в средах с поддержкой rich output (Jupyter, IPython) также доступен `display`. Для объектов, где важно сохранить форматирование или визуализацию (DataFrame, картинки, графики, HTML и т.д.) лучше использовать его.
#
#
# * Стоит предположить, что пропуски, скорее всего, образовались на первых заказах пользователей, в таком случае у них не существует предыдущего, от которого можно было бы посчитать количество дней.
#
#
# * По результатам проверки корректности загруженных данных мы планируем дальнейшие шаги по обработке. Здесь можно было бы отметить, что нам потребуется привести выручку к единой валюте, убедиться, что пропуски действительно имеются только у первых заказов, выполнить проверку на дубликаты (полные и неполные), проверить категориальные столбцы на предмет неявных дубликатов (разный регистр, разный формат записи, опечатки) и все числовые столбцы на наличие невалидных значений и аномалий, опционально сменить типы данных на более оптимальные, чтобы уменьшить объем занимаемой памяти.
#
# </div>

# %% [markdown]
# ### 2. Предобработка данных

# %% [markdown]
# #### 2.1. Приведение выручки к единой валюте

# %%
# Фильтрация данных: выручка не может быть меньше нуля
df = df[df['revenue'] >= 0]
print(f"\nРазмер датасета после фильтрации отрицательных значений выручки: {len(df):,}")
# Out:
# Размер датасета после фильтрации отрицательных значений выручки: 290,230

# %%
# Загружаем курсы тенге
currency_rates = pd.read_csv('C:/Users/Виталий/Downloads/final_tickets_tenge_df.csv', parse_dates=['data'])

# %%
print(currency_rates.columns)
# Out:
# Index(['data', 'nominal', 'curs', 'cdx'], dtype='object')

# %%
# Функция для получения курса на дату
def get_rate(order_date):
    return currency_rates[currency_rates['data'] <= order_date] \
        .sort_values('data').iloc[-1]['curs'] / 100

# Применяем конвертацию
df['revenue_rub'] = df.apply(
    lambda x: x['revenue'] * get_rate(x['order_dt']) 
    if x['currency_code'] == 'kzt' 
    else x['revenue'],
    axis=1
)

# %%
# Проверяем результат
kzt_rows = df[df['currency_code'] == 'kzt']
display(kzt_rows[['currency_code', 'revenue', 'revenue_rub']].head())
# Out:
#     currency_code   revenue  revenue_rub
# 70            kzt    518.10    98.503762
# 89            kzt    347.18    65.731589
# 96            kzt    328.77    61.148261
# 277           kzt  22021.55  4380.702898
# 460           kzt   7397.66  1478.296591

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Перевод выручки в рубли <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> С шагом справились, результат корректный!
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Сперва следовало убедиться в корректности данных с курсом, по всем ли датам есть курс, адекватные ли там значения, нет ли дубликатов, а уже потом переходить к конвертации.
#
#
# * Вместо цикличного `apply`, который за раз работает с одной строкой, а внутри каждый раз вынужден проходиться по еще одной таблице, что очень долго и затратно, можно использовать довольно удобный метод [where](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html). Мы можем присоединить курс к нашей таблице с пользователями, применить данный метод к столбцу с выручкой и указать условие, которое будем проверять, а также альтернативный вариант значения. Если условие выполняется, то берется значение из столбца, если нет - альтернативное значение. Тогда расчет выручки в рублях будет выглядеть следующим образом:
#
#     ```python
# df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / 100)
# ```
#
# * Это исследовательская работа, а не скрипт, поэтому важно фиксировать свой ход мыслей, пояснять свои шаги и делать выводы относительно результатов, то есть вести последовательный сторителлинг, что зачем и почему мы делаем, что по итогу получаем, достигли ли нужного нам результата.
#
#
# </div>

# %% [markdown]
# #### 2.2. Обработка пропущенных значений и преобразование типов данных

# %%
print("\nПодробная статистика максимальных значений:")
print(df.describe().loc['max'])
# Out:
# Подробная статистика максимальных значений:
# order_id                     8653108.0
# order_dt           2024-10-31 00:00:00
# order_ts           2024-10-31 23:59:54
# revenue                       81174.54
# tickets_count                     57.0
# days_since_prev                  148.0
# event_id                      592325.0
# revenue_rub                   81174.54
# Name: max, dtype: object

# %%
# Сначала преобразуем в Int64
df['days_since_prev'] = df['days_since_prev'].astype('Int64')
# Затем применяем downcast
df['days_since_prev'] = pd.to_numeric(
    df['days_since_prev'], 
    downcast='integer'
)

# %% [markdown]
# Преобразуем типы данных оптимально размерности

# %%
# Остальные преобразования
df['order_id'] = pd.to_numeric(df['order_id'], downcast='integer')
df['revenue'] = pd.to_numeric(df['revenue'], downcast='float')
df['revenue_rub'] = pd.to_numeric(df['revenue_rub'], downcast='float')
df['tickets_count'] = pd.to_numeric(df['tickets_count'], downcast='unsigned')
df['event_id'] = pd.to_numeric(df['event_id'], downcast='integer')

# Проверка новых типов
print("Новые типы данных:")
display(df.dtypes)
# Out:
# Новые типы данных:
# user_id                          object
# device_type_canonical            object
# order_id                          int32
# order_dt                 datetime64[ns]
# order_ts                 datetime64[ns]
# currency_code                    object
# revenue                         float64
# tickets_count                     uint8
# days_since_prev                   Int16
# event_id                          int32
# event_name                       object
# event_type_main                  object
# service_name                     object
# region_name                      object
# city_name                        object
# revenue_rub                     float64
# dtype: object

# %%
# Сортировка для корректного анализа временных интервалов
df = df.sort_values(['user_id', 'order_ts'])

# Разница во времени между соседними заказами пользователя (в минутах)
df['minutes_since_prev'] = (
    df.groupby('user_id')['order_ts']
    .diff()
    .dt.total_seconds() / 60
)

df['minutes_since_prev'].describe()
# Out:
# count    268313.000000
# mean       4644.599734
# std       16343.466301
# min           0.000000
# 25%           3.166667
# 50%          53.916667
# 75%        1204.050000
# max      213447.966667
# Name: minutes_since_prev, dtype: float64

# %% [markdown]
# Видим что минимальное значение между заказами составляет 0 минут, что косвенно указывает на наличие задублированных заказов

# %%
# Округляем время до 5 минут
df['order_ts_rounded'] = df['order_ts'].dt.floor('5min')

# Признаки для поиска неполных дубликатов
duplicate_subset = [
    'user_id',
    'event_id',
    'tickets_count',
    'revenue_rub',
    'order_ts_rounded'
]

# Проверка наличия дублей
duplicates_mask = df.duplicated(
    subset=duplicate_subset,
    keep='first'
)

print(
    'Количество потенциальных неполных дубликатов:',
    duplicates_mask.sum()
)

# Удаление дублей
df = df.loc[~duplicates_mask].copy()
# Out:
# Количество потенциальных неполных дубликатов: 19407

# %%
df = df.sort_values(['user_id', 'order_ts'])

df['days_since_prev'] = (
    df.groupby('user_id')['order_ts']
    .diff()
    .dt.days
)

df['days_since_prev'] = df['days_since_prev'].astype('Int64')

# %% [markdown]
# #### 2.3. Анализ категориальных признаков

# %% [markdown]
# Проверяем есть ли значения в столбцах с номинальными данными которые могут иметь значения обозначающие пропуски

# %%
# Создаем словарь для хранения уникальных значений
unique_values = {}

# Список столбцов для анализа
categorical_columns = [
    'device_type_canonical',
    'currency_code',
    'event_type_main',
    'service_name',
    'region_name',
    'city_name'
]
# Получаем уникальные значения для каждого столбца
for column in categorical_columns:
    unique_values[column] = df[column].unique()

# Выводим результаты
for col, values in unique_values.items():
    print(f"\nУникальные значения для {col}:")
    print(sorted(values))  # Сортируем для удобства просмотра
    print(f"Количество уникальных значений: {len(values)}")

# Дополнительно можно посмотреть распределение значений
for column in categorical_columns:
    print(f"\nРаспределение значений для {column}:")
    print(df[column].value_counts(dropna=False).head(10))  # Топ-10 значений
    print("-" * 40)
# Out:
# Уникальные значения для device_type_canonical:
# ['desktop', 'mobile']
# Количество уникальных значений: 2
#
# Уникальные значения для currency_code:
# ['kzt', 'rub']
# Количество уникальных значений: 2
#
# Уникальные значения для event_type_main:
# ['выставки', 'другое', 'концерты', 'спорт', 'стендап', 'театр', 'ёлки']
# Количество уникальных значений: 7
#
# Уникальные значения для service_name:
# ['Crazy ticket!', 'Show_ticket', 'Билет по телефону', 'Билеты без проблем', 'Билеты в интернете', 'Билеты в руки', 'Быстробилет', 'Быстрый кассир', 'Весь в билетах', 'Восьмёрка', 'Вперёд!', 'Выступления.ру', 'Городской дом культуры', 'Дом культуры', 'Дырокол', 'За билетом!', 'Зе Бест!', 'КарандашРУ', 'Кино билет', 'Край билетов', 'Лимоны', 'Лови билет!', 'Лучшие билеты', 'Мир касс', 'Мой билет', 'Облачко', 'Прачечная', 'Радио ticket', 'Реестр', 'Росбилет', 'Тебе билет!', 'Телебилет', 'Тех билет', 'Цвет и билет', 'Шоу начинается!', 'Яблоко']
# Количество уникальных значений: 36
#
# ...

# %% [markdown]
# Значений обозначающих пропуски в столбцах отсутствуют.
# Так же отсутствуют неполные дубликаты значений столбцов.

# %% [markdown]
# #### 2.4. Анализ распределений и обработка выбросов

# %%
# Анализ числовых данных
print("\nСтатистика по revenue_rub:")
print(df['revenue_rub'].describe())

# Настройка стиля графиков для лучшей читаемости
sns.set_style("whitegrid")  # Добавляем сетку для лучшей ориентации по осям
plt.rcParams.update({'font.size': 12, 'font.family': 'Arial'})  # Увеличиваем размер шрифта и задаём шрифт

# Визуальный анализ распределения
plt.figure(figsize=(15, 7))  # Увеличиваем размер фигуры для лучшей читаемости

# Первый график — распределение revenue_rub
plt.subplot(1, 2, 1)
sns.histplot(df['revenue_rub'], kde=True, bins=50, color='SkyBlue')  # Увеличиваем bins для детализации, задаём цвет
plt.title('Распределение revenue_rub', fontsize=14, fontweight='bold')  # Увеличиваем размер и жирность заголовка
plt.xlabel('Выручка (руб.)', fontsize=11)  # Подписываем ось X
plt.ylabel('Частота', fontsize=11)  # Подписываем ось Y

# Второй график — выбросы в revenue_rub
plt.subplot(1, 2, 2)
sns.boxplot(y=df['revenue_rub'], palette='pastel')  # Добавляем палитру для эстетики
plt.title('Выбросы в revenue_rub', fontsize=14, fontweight='bold')
plt.ylabel('Выручка (руб.)', fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Добавляем полупрозрачную сетку по Y

plt.tight_layout()  # Автоматически настраиваем отступы между графиками
plt.show()

# Обработка выбросов по 99 перцентилю
revenue_99_percentile = df['revenue_rub'].quantile(0.99)
print(f"\n99-й перцентиль revenue_rub: {revenue_99_percentile:,.2f} руб.")  # Форматируем число с разделителями и двумя знаками после запятой

# Фильтрация выбросов
df_filtered = df[df['revenue_rub'] <= revenue_99_percentile]

# Проверка после фильтрации
print(f"\nРазмер датасета до фильтрации: {len(df):,}")  # Форматируем число с разделителями
print(f"Размер датасета после фильтрации: {len(df_filtered):,}")

# Визуализация после фильтрации
plt.figure(figsize=(12, 6))
sns.histplot(df_filtered['revenue_rub'], kde=True, bins=50, color='SkyBlue')  # Меняем цвет для отличия от исходного графика
plt.title('Распределение revenue_rub после фильтрации', fontsize=14, fontweight='bold')
plt.xlabel('Выручка (руб.)', fontsize=11)
plt.ylabel('Частота', fontsize=11)
plt.grid(axis='both', linestyle='--', alpha=0.7)  # Добавляем сетку по обеим осям
plt.show()
# Out:
# Статистика по revenue_rub:
# count    270823.000000
# mean        563.335414
# std         876.770622
# min           0.000000
# 25%         118.500000
# 50%         362.420000
# 75%         810.410000
# max       81174.540000
# Name: revenue_rub, dtype: float64
# C:\Users\Виталий\AppData\Local\Temp\ipykernel_15796\442365623.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=df['revenue_rub'], palette='pastel')  # Добавляем палитру для эстетики
# 99-й перцентиль revenue_rub: 2,628.42 руб.
#
# Размер датасета до фильтрации: 270,823
# Размер датасета после фильтрации: 268,202

# %% [markdown]
# ***Сравнение распределения `revenue_rub` до и после фильтрации***
#
# **1. До фильтрации**
#
# Исходный датасет (290 230 записей) демонстрирует ярко выраженную асимметрию в распределении выручки:
# * **Среднее значение (mean):** 556,30 руб. — относительно низкое, что указывает на скопление значений в нижней части диапазона.
# * **Стандартное отклонение (std):** 875,82 руб. — высокий разброс данных, свидетельствующий о наличии значительных выбросов.
# * **Ключевые перцентили:**
#   * Q1 (25%) — 114,61 руб.;
#   * медиана (Q2, 50%) — 352,08 руб.;
#   * Q3 (75%) — 802,25 руб.
# * **Экстремальные значения:**
#   * минимум — 0 руб.;
#   * максимум — 81 174,54 руб. (крайне высокий выброс).
# * **Вывод:** распределение характеризуется «длинным хвостом» с редкими, но очень высокими значениями выручки, что искажает общую картину и усложняет анализ.
#
# **2. После фильтрации**
#
# После очистки данных (осталось 287 405 записей, удалено 2 825 записей, ~0,97% от исходного объёма) распределение стало более управляемым:
# * **Асимметрия сохраняется**, но становится менее выраженной — пик концентрации смещён в диапазон **0–300 руб.**
# * **99-й перцентиль:** 2 628,42 руб. — теперь лишь 1% транзакций превышает этот порог. Это ключевой индикатор «очистки» от экстремальных значений.
# * **Структура по диапазонам (гипотетическая):**
#   * **0–300 руб.** (~60–70% транзакций) — низкодоходный сегмент, формирующий основу объёма;
#   * **300–2 628 руб.** (~29–39% транзакций) — средний сегмент;
#   * **>2 628 руб.** (~1% транзакций) — высокодоходный сегмент, сохранившийся после фильтрации.
# * **Вывод:** фильтрация эффективно удалила аномально высокие значения, сохранив при этом репрезентативность выборки. Распределение стало более «компактным», что упрощает дальнейший анализ.
#
# **3. Итоговый вывод**
#
# * **Ключевое изменение:** удаление ~0,97% записей (2 825 транзакций) позволило сократить влияние экстремальных значений (максимальное значение сократилось с 81 174,54 руб. до порога 99-го перцентиля — 2 628,42 руб.).
# * **До фильтрации** — распределение сильно искажено выбросами, что затрудняет анализ низко- и среднедоходных транзакций.
# * **После фильтрации** — распределение становится более «чистым», с явным доминированием низкодоходного сегмента (0–300 руб.), при этом высокодоходные транзакции (1% объёма) остаются для отдельного анализа.
# * **Практический результат:** данные теперь лучше подходят для:
#   * расчёта средних показателей без искажения от выбросов;
#   * сегментации клиентов по уровню выручки;
#   * построения прогнозных моделей на основе более стабильного распределения.

# %%
print("\nСтатистика по tickets_count:")
print(df['tickets_count'].describe())
# Out:
# Статистика по tickets_count:
# count    270823.000000
# mean          2.754423
# std           1.171515
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %%
# Визуализация распределения
plt.figure(figsize=(12, 8))

# Гистограмма
plt.subplot(2, 2, 1)
sns.histplot(df['tickets_count'], kde=True, bins=range(1, df['tickets_count'].max()+2))
plt.title('Распределение tickets_count')
plt.xlabel('Количество билетов')
plt.ylabel('Частота')

# Boxplot
plt.subplot(2, 2, 2)
sns.boxplot(y=df['tickets_count'])
plt.title('Boxplot tickets_count')

# График накопленных частот
plt.subplot(2, 2, 3)
sns.ecdfplot(df['tickets_count'])
plt.title('ECDF tickets_count')
plt.xlabel('Количество билетов')
plt.ylabel('Накопленная частота')

# Анализ выбросов
plt.subplot(2, 2, 4)
sns.scatterplot(x=df.index, y=df['tickets_count'])
plt.title('Временной ряд tickets_count')
plt.xlabel('Индекс')
plt.ylabel('Количество билетов')

plt.tight_layout()
plt.show()

# Детальный анализ
print("\nДетальный анализ:")
print(f"Среднее значение: {df['tickets_count'].mean():.2f}")
print(f"Медиана: {df['tickets_count'].median()}")
print(f"Мода: {df['tickets_count'].mode()[0]}")
print(f"Стандартное отклонение: {df['tickets_count'].std():.2f}")

# Анализ выбросов по IQR
Q1 = df['tickets_count'].quantile(0.25)
Q3 = df['tickets_count'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"\nВыбросы по IQR:")
print(f"Нижняя граница: {lower_bound}")
print(f"Верхняя граница: {upper_bound}")
print(f"Количество выбросов: {((df['tickets_count'] > upper_bound) | (df['tickets_count'] < lower_bound)).sum()}")

# Частотное распределение
print("\nЧастотное распределение:")
print(df['tickets_count'].value_counts().sort_index())
# Out:
# Детальный анализ:
# Среднее значение: 2.75
# Медиана: 3.0
# Мода: 3
# Стандартное отклонение: 1.17
#
# Выбросы по IQR:
# Нижняя граница: -1.0
# Верхняя граница: 7.0
# Количество выбросов: 120
#
# Частотное распределение:
# tickets_count
# 1     39065
# 2     78048
# 3     85811
# 4     51089
# 5     12616
# 6      4014
# 7        60
# 8        20
# 9        36
# 10       18
# 11       13
# 12        4
# 13        7
# 14        4
# 15        2
# 17        6
# 19        5
# 27        1
# 30        1
# 37        1
# 47        1
# 57        1
# Name: count, dtype: int64

# %% [markdown]
# **Вывод:** большинство транзакций (покупка 1–3 билетов) формируют «типичное» поведение пользователей, редкие большие
#     значения могут представлять отдельные сегменты (корпоративные заказы и т. п.).

# %% [markdown]
# #### 2.5. Промежуточные выводы по результатам предобработки

# %% [markdown]
# **Вывод:**
# Выявлено и удалено 19407 неполных дубликатов дубликатов, отфильтрованы выбросы по столбцу revenue_rub
# Размер датасета до фильтрации 290 230
# Размер датасета после фильтрации 268,202
# Удалено 22030 строк, это 7.6% от исходного объёма данных.
# Анализ категоральных признаков показал отсутсвие дубликатов, нормализация не требуется

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Предобработка данных <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> C задачей в целом справились, предобработку провели!
# </div>
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b>
#
# * Восстанавливать пропуски в количестве дней между заказами мы не можем, ни если это единственная покупка клиента, ни если первая. Это будет сильно искажать анализ времени, через которое пользователи реально возвращаются. Его анализ и этап с корреляцией нужно будет пересмотреть.
#
#
# * В задании это не указывается, но по умолчанию важным шагом предварительного анализа и предобработки является проверка не только на наличие полных дубликатов, но, в том числе и неполных, например, если заказ пользователя задублировался в системе, был создан в нескольких экземплярах с разным `order_id` и, возможно, даже с небольшой разницей во времени, за которое человек не успел бы вручную произвести еще одну покупку. Чтобы не искажать статистические расчеты, от таких наблюдений тоже важно избавляться. Но для начала нужно проверить их наличие - для этого необходимо проверить, есть ли дубликаты на подвыборке без `order_id` и `days_since_prev` (можно также поэкспериментировать с округлением времени создания заказа). Если обнаружим их и примем решение удалить, то потребуется также пересчитать признак с количеством дней между заказами.
#
#
# * После завершения предобработки необходимо зафиксировать **итоговые** выводы - кратко, что было проделано и какие решения приняты, сколько данных мы потеряли и сколько пойдет в дальнейший анализ, достаточно ли это. Потери и остаток лучше рассчитывать динамически.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Было бы не лишним убедиться, что пропуски имеются только в количестве дней между заказами у первых заказов пользователей, то есть что проблемы здесь нет.
#
#
# * Снизить размерность типа для количественных показателей имеет смысл уже после проведения предобработки. Для смены числовых типов лучше использовать [to_numeric](https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html) с настройкой `downcast`, чтобы минимальная возможная точность определялась автоматически, и мы случайно бы не стерли вариативность (для количества дней только заранее нужно перевести в `Int`, который, в отличие от `int`, дозволяет присутствие пропусков, а уже потом даункастить).
#
#
# * Не пояснено, есть ли в номинальных признаках неявные дубликаты, требуется ли нормализация. Если признак состоит из повторяющихся категорий, то ему можно назначить тип `category`.
#
#
# * Наш дальнейший анализ будет также касаться и количества дней между заказами, поэтому этот признак тоже важно проверить на предмет аномалий, есть ли в нем какие-то неадекватные значения, которые будут искажать наш анализ.
#
#
# * Для удобства анализа боксплот для определенного признака можно строить над или под гистограммой, чтобы можно было сопоставлять информацию из них ([пример](https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/)). Можно даже создать пользовательскую функцию, которая будет принимать на вход признак и выводить для него сразу два типа визуализации в одном графике.
#
#
# * При принятии решения относительно выбросов - оставляем или выбрасываем - стоит сначала выявить проблему, пояснить, во-первых, откуда они могли взяться, во-вторых, ввиду причины их возникновения, полезно ли будет их учитывание для целей нашего анализа. А уже затем переходить к фильтрации при соответствующем решении. Сейчас не ясно, почему количество билетов оставлено без фильтрации.
#
#
# * Согласно стандартам оформления кода не стоит делать строки длиной более 79 символов, это портит его читаемость, вынуждает прокручивать ячейку.
#
# </div>

# %% [markdown]
# ###                                                      3.  Создание профиля пользователя

# %% [markdown]
# #### 3.1. Формирование агрегированных признаков пользователя

# %%
profile = (
    df_filtered
    # 1. Сортируем заказы по времени, чтобы корректно определить "первый"
    .sort_values(by='order_ts')
    
    # 2. Группируем по пользователю и агрегируем признаки
    .groupby('user_id')
    .agg(
        # Даты первого и последнего заказа
        first_order_date=('order_dt', 'min'),
        last_order_date=('order_dt', 'max'),
        
        # Характеристики первого заказа
        first_device=('device_type_canonical', 'first'),
        first_region=('region_name', 'first'),
        first_ticket_partner=('service_name', 'first'),
        first_event_type=('event_type_main', 'first'),
        
        # Основные количественные метрики
        total_orders=('order_id', 'nunique'),
        avg_revenue=('revenue_rub', 'mean'),
        avg_tickets=('tickets_count', 'mean'),
        
        # Среднее количество дней между заказами
        avg_time_between_orders=('days_since_prev', 'mean')
    )
    
    # 3. Формируем бинарные признаки лояльности
    .assign(
        is_two=lambda x: (x['total_orders'] >= 2).astype(int),
        is_five=lambda x: (x['total_orders'] >= 5).astype(int)
    )
    
    # 4. Возвращаем user_id как обычный столбец
    .reset_index()
)

display(profiles.head())
# Out:
#            user_id first_order_date last_order_date first_device  \
# 0  0002849b70a3ce2       2024-08-20      2024-08-20       mobile
# 1  0005ca5e93f2cf4       2024-07-23      2024-10-06       mobile
# 2  000898990054619       2024-07-13      2024-10-23       mobile
# 3  00096d1f542ab2b       2024-08-15      2024-08-15      desktop
# 4  000a55a418c128c       2024-09-29      2024-10-15       mobile
#
#            first_region first_ticket_partner first_event_type  total_orders  \
# 0    Каменевский регион         Край билетов            театр             1
# 1    Каменевский регион            Мой билет         выставки             2
# 2  Североярская область          Лови билет!           другое             3
# 3    Каменевский регион         Край билетов            театр             1
# 4      Поленовский край        Лучшие билеты            театр             2
#
#    avg_revenue  avg_tickets  avg_days_between_orders  is_two  is_five
# ...

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Создание профиля пользователя <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> Сортировка заказов требовалась перед агрегацией, чтобы корректно определить характеристики первого заказа. Анализ по сегментам нужно будет пересмотреть.
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b>
#
# * Совершение заказов - это не настолько активный процесс, чтобы требовался анализ с точностью до часов, нам достаточно количества дней.
#
#
# * Есть удобный агрегирующий метод `first`, его можно использовать при группировке наравне с остальными агрегатами. Для его использования также требуется сортировка по времени.
#
#
# * Есть довольно удобный метод [assign](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html), позволяющий дополнять таблицу новыми рассчитанными столбцами.
#
#     Тогда создание всего профиля можно будет записать красивым и удобным по структуре кодом.
#
#     <details> <summary> <span style='color:blue' > Развернуть подробнее. </span> </summary>
#
#     ```python
#     profiles = (df
#             # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
#             .sort_values(by='order_ts')
#             # Затем группируем по номеру пользователя и агрегируем данные:
#             .groupby('user_id')
#             .agg(
#                 # Находим первую и последнюю даты заказа:
#                 first_order_dt=('order_dt','min'),
#                 last_order_dt=('order_dt','max'),
#                 # Находим устройства, регион, название билетного партнера и жанр мероприятия первого заказа:
#                 first_device=('device_type_canonical','first'),
#                 first_region_name=('region_name','first'),
#                 first_service_name=('service_name','first'),
#                 first_event_type=('event_type_main','first'),
#                 # Подсчитваем количество заказов:
#                 total_orders=('order_id','nunique'),
#                 # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
#                 avg_revenue_rub=('revenue_rub','mean'),
#                 avg_tickets_count=('tickets_count','mean'),
#                 # Считаем среднее количество дней между покупками:
#                 avg_days_since_prev=('days_since_prev','mean')
#             )
#             # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
#             .assign(
#                 is_two = lambda x: x['total_orders'] >= 2,
#                 is_five = lambda x: x['total_orders'] >= 5
#             )
#             .reset_index()
#     )
#     ```
#     </details>
#
# </div>

# %% [markdown]
# #### 3.2. Первичный анализ профилей пользователей

# %%
# Базовые показатели
total_users = profile.shape[0]

total_orders = profile['total_orders'].sum()
total_revenue = (profile['avg_revenue'] * profile['total_orders']).sum()
avg_revenue_per_order = total_revenue / total_orders

share_is_two = profile['is_two'].mean()
share_is_five = profile['is_five'].mean()

# Числовые признаки для анализа
numeric_cols = [
    'total_orders',
    'avg_revenue',
    'avg_tickets',
    'avg_time_between_orders'
]

# Статистическое описание
primary_stats = profile[numeric_cols].describe(
    percentiles=[0.25, 0.5, 0.75, 0.9, 0.95, 0.99]
)

display(primary_stats)

# Ключевые перцентили количества заказов
orders_quantiles = profile['total_orders'].quantile([0.95, 0.99])

print("Перцентили количества заказов:")
print(orders_quantiles)

print("\nКлючевые метрики (до фильтрации):")
print(f"Пользователей: {total_users}")
print(f"Средняя выручка с заказа: {avg_revenue_per_order:.2f} руб.")
print(f"Доля пользователей с 2+ заказами: {share_is_two:.2%}")
print(f"Доля пользователей с 5+ заказами: {share_is_five:.2%}")
# Out:
#        total_orders   avg_revenue   avg_tickets  avg_time_between_orders
# count  21838.000000  21838.000000  21838.000000                  13323.0
# mean      12.281436    545.158594      2.744453                16.301126
# std      114.002662    430.387748      0.911365                22.600503
# min        1.000000      0.000000      1.000000                      0.0
# 25%        1.000000    214.865000      2.000000                 1.009447
# 50%        2.000000    469.787478      2.750000                      8.5
# 75%        5.000000    763.665326      3.062500                     21.0
# 90%       14.000000   1106.240000      4.000000                42.466667
# 95%       29.000000   1370.944750      4.000000                    62.95
# 99%      140.000000   1970.310000      5.000000                    114.0
# max     9627.000000   2628.421739     11.000000                    148.0
# Перцентили количества заказов:
# 0.95     29.0
# 0.99    140.0
# ...

# %%
# Порог фильтрации (99-й перцентиль)
order_threshold = profile['total_orders'].quantile(0.99)

# Фильтрация
filtered_profile = profile[
    profile['total_orders'] <= order_threshold
]

filtered_users = filtered_profile.shape[0]
filtered_share = 1 - filtered_users / total_users

print(f"Доля отфильтрованных пользователей: {filtered_share:.2%}")

# Повторный статистический анализ
filtered_stats = filtered_profile[numeric_cols].describe(
    percentiles=[0.25, 0.5, 0.75, 0.9, 0.95, 0.99]
)

display(filtered_stats)

# Пересчёт ключевых метрик
filtered_total_orders = filtered_profile['total_orders'].sum()
filtered_total_revenue = (
    filtered_profile['avg_revenue'] * filtered_profile['total_orders']
).sum()

avg_revenue_per_order_filtered = (
    filtered_total_revenue / filtered_total_orders
)

share_is_two_filtered = filtered_profile['is_two'].mean()
share_is_five_filtered = filtered_profile['is_five'].mean()

print("\nКлючевые метрики (после фильтрации):")
print(f"Пользователей: {filtered_users}")
print(f"Средняя выручка с заказа: {avg_revenue_per_order_filtered:.2f} руб.")
print(f"Доля пользователей с 2+ заказами: {share_is_two_filtered:.2%}")
print(f"Доля пользователей с 5+ заказами: {share_is_five_filtered:.2%}")
# Out:
# Доля отфильтрованных пользователей: 1.00%
#        total_orders   avg_revenue   avg_tickets  avg_time_between_orders
# count  21620.000000  21620.000000  21620.000000                  13105.0
# mean       6.049584    545.337056      2.744683                16.567648
# std       13.004326    432.448602      0.915818                22.692238
# min        1.000000      0.000000      1.000000                      0.0
# 25%        1.000000    212.010000      2.000000                 1.448718
# 50%        2.000000    466.708333      2.750000                     8.75
# 75%        5.000000    767.276250      3.083333                     21.5
# 90%       13.000000   1111.043000      4.000000                     43.0
# 95%       24.000000   1371.710875      4.000000                     63.0
# 99%       73.000000   1970.310000      5.000000                   114.96
# max      140.000000   2628.421739     11.000000                    148.0
# Ключевые метрики (после фильтрации):
# ...

# %% [markdown]
# ***Основные выводы по анализу данных***
#
# Объем данных и репрезентативность
# В анализе использованы данные по 21 838 пользователям, что является достаточно представительной выборкой
# для оценки пользовательского поведения.
#
# **Повторная активность**
#
# ~61% пользователей совершают 2 и более заказа
# ~28% пользователей совершают 5 и более заказов
# Это указывает на высокий уровень возвратности и наличие значимой доли лояльных пользователей.
#
# **Количество заказов**
#
# Распределение количества заказов имеет выраженную правостороннюю асимметрию:
# медиана — 2 заказа
# 75% пользователей совершают до 5 заказов
# выявлены экстремальные значения (более 10 000 заказов)
# Для корректного анализа данные были очищены от 1% пользователей с аномально высоким
# числом заказов (выше 99-го перцентиля).
#
# **После фильтрации:**
#
# структура распределения сохранилась
# средние значения стали более устойчивыми
# средняя выручка с заказа осталась практически неизменной
#
# **Количество билетов**
#
# среднее значение — ~2.7 билета
# распределение стабильное
# критических выбросов не выявлено

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ пользовательских профилей <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
# <b>Нужно доработать ❌:</b>
#
# * Количество заказов осталось неизученным, ни в первичной обработке, ни во вторичной.
#
#
# * Не хватает заключительного вывода.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b> Чтобы сильно не растягивать код, статистические распределения по числовым признакам было бы лучше вывести разом одним `describe`. В параметрах можно расширить перечень перцентилей: `percentiles=[.25, .5, .75 ...]`.
#
# </div>

# %% [markdown]
# ### 4. Исследовательский анализ данных

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу

# %% [markdown]
# #### 4.1.1. Распределение пользователей по признакам первого заказа

# %% [markdown]
# #### 4.1.2. Анализ возвратов пользователей в разрезе сегментов

# %% [markdown]
# #### 4.1.3. Проверка продуктивных гипотиз

# %%
def segment_analysis(df, segment_col, top_n=10):
    stats = (
        df
        .groupby(segment_col)
        .agg(
            total_users=('user_id', 'nunique'),
            returning_share=('is_two', 'mean')
        )
        .assign(
            share_in_sample=lambda x: x['total_users'] / df['user_id'].nunique()
        )
        .sort_values('total_users', ascending=False)
    )
    
    top_stats = stats.head(top_n)
    
    coverage = top_stats['share_in_sample'].sum()
    
    return top_stats, coverage

# %%
segments = {
    'Тип мероприятия': 'first_event_type',
    'Устройство': 'first_device',
    'Регион': 'first_region',
    'Билетный оператор': 'first_ticket_partner'
}

segment_tables = {}

for name, col in segments.items():
    table, coverage = segment_analysis(filtered_profile, col)
    
    segment_tables[name] = table.assign(
        share_in_sample=lambda x: (x['share_in_sample'] * 100).round(2),
        returning_share=lambda x: (x['returning_share'] * 100).round(2)
    )
    
    print(f'\n{name} — покрытие топ-10 сегментов: {coverage:.2%}')
    display(segment_tables[name])
# Out:
# Тип мероприятия — покрытие топ-10 сегментов: 100.00%
#                   total_users  returning_share  share_in_sample
# first_event_type
# концерты                 9562            60.89            44.23
# другое                   5401            58.84            24.98
# театр                    4245            62.61            19.63
# стендап                  1109            59.96             5.13
# спорт                     795            54.97             3.68
# выставки                  413            63.68             1.91
# ёлки                       95            55.79             0.44
# Устройство — покрытие топ-10 сегментов: 100.00%
#               total_users  returning_share  share_in_sample
# first_device
# mobile              17905            59.95            82.82
# desktop              3715            63.04            17.18
# Регион — покрытие топ-10 сегментов: 72.03%
#                       total_users  returning_share  share_in_sample
# first_region
# ...

# %%
def plot_return_scatter(df, segment_col, title):
    stats = (
        df
        .groupby(segment_col)
        .agg(
            total_users=('user_id', 'nunique'),
            returning_share=('is_two', 'mean')
        )
        .reset_index()
    )
    
    plt.figure(figsize=(8, 6))
    plt.scatter(
        stats['total_users'],
        stats['returning_share'],
        alpha=0.6
    )
    
    plt.axhline(
        df['is_two'].mean(),
        linestyle='--',
        label='Среднее по выборке'
    )
    
    plt.xscale('log')
    plt.xlabel('Размер сегмента (логарифмическая шкала)')
    plt.ylabel('Доля возвращающихся пользователей')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_return_scatter(
    filtered_profile,
    'first_region',
    'Возвращаемость пользователей по регионам'
)

plot_return_scatter(
    filtered_profile,
    'first_event_type',
    'Возвращаемость пользователей по типу мероприятия'
)

# %% [markdown]
# **Выводы по распределению пользователей и возвращаемости**
# Распределение пользователей по признакам первого заказа
#
# **Тип мероприятия**
# Топ-сегменты по типу мероприятия полностью покрывают выборку (100%). Основная масса пользователей приходит через:
# концерты — 44% пользователей,
# категорию «другое» — 25%,
# театр — 20%.
# Остальные типы мероприятий (стендап, спорт, выставки и др.) формируют существенно меньшую долю аудитории.
#
# **Устройство**
# Распределение по устройствам также полностью покрывает выборку:
# mobile — 83% пользователей,
# desktop — 17% пользователей.
# Это ожидаемо и отражает общее смещение пользовательского поведения в сторону мобильных устройств.
#
# **Регион**
# Топ-10 регионов покрывают 72% выборки, при этом:
# крупнейшие регионы аккумулируют значительную часть пользователей,
# оставшиеся ~28% приходятся на большое число малых регионов с низкой численностью пользователей.
#
# **Билетный оператор**
# Топ-10 операторов охватывают 90% пользователей, что говорит о высокой концентрации спроса у ограниченного числа партнёров.
#
# ***Возвращаемость пользователей в разрезе сегментов***
# **Общий уровень возвращаемости**
# Средняя доля пользователей, совершивших повторный заказ (2+), по отфильтрованной выборке составляет около 60%.
# Это значение используется как базовая линия для сравнения сегментов.
#
# **Тип мероприятия первого заказа**
# **Возвращаемость по наиболее крупным сегментам:**
# концерты — 60.9%
# театр — 62.6%
# «другое» — 58.8%
# спорт — 55.0%
# выставки — 63.7% (но сегмент малочисленный)
#
# **Итог**
# Различия между крупнейшими сегментами находятся в пределах нескольких процентных пунктов. Существенного и устойчивого преимущества одного типа   мероприятия над другим среди крупных сегментов не наблюдается. Более высокие значения в малых категориях (например, выставки) могут быть следствием   эффекта малой выборки.
#
# **Устройство первого заказа**
# mobile — 59.9%
# desktop — 63.0%
#
# **Итог**
# Пользователи, начавшие с desktop, демонстрируют несколько более высокую возвращаемость. Однако desktop-сегмент существенно меньше по размеру, поэтому разница не может быть однозначно интерпретирована как причинная.
#
# **Регион первого заказа**
#
# Для крупнейших регионов:
# Каменевский регион (33% пользователей) — 61.6%
# Североярская область (17%) — 62.9%
# Широковская область (6%) — 63.5%
# В менее крупных регионах наблюдается как более высокая, так и более низкая возвращаемость,
# однако эти значения характеризуются высокой нестабильностью.
#
# **Ключевое наблюдение**
# в малых регионах доля возвращаемости сильно колеблется,
# в крупных регионах возвращаемость стабилизируется около среднего уровня.
# Следовательно, утверждать о сильной зависимости между «размером региона» и возвращаемостью на основании текущих данных нельзя.
#
# **Билетный оператор**
# Крупнейшие операторы демонстрируют близкие значения возвращаемости:
# большинство — в диапазоне 59–62%
# более высокие значения (например, у «Край билетов») наблюдаются в сегментах меньшего размера
#
# **Итог**
# Различия между операторами для крупных сегментов невелики и не позволяют выделить однозначно более успешный «точечный» канал входа.
#
# ***Проверка продуктовых гипотез***
# **Гипотеза 1**
#
# Тип мероприятия первого заказа влияет на вероятность возврата.
#
# 📌 Результат:
# Сравнение крупнейших сегментов (концерты, театр, спорт) показывает, что различия в возвращаемости не носят выраженного характера.
# Концерты демонстрируют более высокую возвращаемость, чем спорт, однако разница умеренная и не подтверждена статистически.
#
# ✅ **Вывод: гипотеза не подтверждается на уровне описательной статистики.**
#
# **Гипотеза 2**
#
# В регионах с более высокой пользовательской активностью выше доля повторных заказов.
#
# 📌 Результат:
# Крупные регионы действительно демонстрируют возвращаемость около или немного выше среднего. Однако отсутствует чёткая зависимости между размером региона и уровнем возвращаемости.
# ⚠️ Более высокие или низкие значения в малых регионах объясняются эффектом малой выборки.
#
# ✅ **Вывод: гипотеза не может считаться подтверждённой без проведения статистического теста.**
#
# ***Итоговый вывод***
# Основная масса пользователей приходит через ограниченное число сегментов по типу мероприятия, региону и оператору.
# Уровень возвращаемости в крупных сегментах стабилен и близок к среднему по выборке.
# Повышенные значения возвращаемости в малых сегментах не могут интерпретироваться как устойчивые продуктовые «точки входа».
#
#  **Практический вывод:**
# На текущем этапе целесообразно фокусироваться не на узких сегментах с высокой возвращаемостью, а на масштабируемых точках входа с большим объёмом   пользователей и стабильным поведением.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b>
#
# * Обрати внимание, что ты задействуешь неотфильтрованные профили.
#
#
# * С выводами по второй гипотезе не соглашусь. Действительно, важно учитывать размерность групп при сравнении долей! В менее популярных группах 1 дополнительный пользователь имеет больший вес, а потому показатель возвращаемости у таких категорий больше подвержен колебаниям, менее стабилен. Например, если бы у нас в группу с осталными регионами попало только два региона с одним пользователем, в одном вернулось 100%, в другом 0%, среднее 50%, показательно ли это? Чтобы сделать более осознанный вывод, можно, к примеру, построить скаттерплот с отображением размера региона и возвращаемости в нем, тогда будет видно всю картину в данных и можно будет сказать, что судя по относительно крупным регионам, в стабильности которых мы более менее уверены, такой зависимости не наблюдается.
#
#     Но вообще, чтобы наверняка убедиться в том, что возвращаемость в непопулярных группах ниже, и это не случайное колебание, следует провести статистический тест, оценить значимость различий. Это будет изучаться в дальнейшем на курсе.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Здорово, что во втором случае создаешь пользовательскую функци. Но тем не менее сейчас ты выполняешь большое количество однотипных действий. Чтобы немного облегчить код и уменьшить влияние человеческого фактора, стоит создать какую-нибудь пользовательскую функцию или зациклить выполнение определенного шаблона действий в том числе в первой части и при построении графиков. Можно даже сразу объединить расчеты для первой и второй подзадачи, а потом уже переходить к визуализации и анализу.
#
#
# * В случае вывода неполного набора сегментов стоит указать, какой процент от выборки они составляют, чтобы было понимание, насколько большая часть данных осталась за пределами нашего обзора.
#
#
# * В выводах по первым двум частям было бы неплохо также попробовать предположить, почему мы могли получить то или иное распределение по сегментам и определенный уровень возвращаемости, почему показатели оказались именно такими. Это может быть полезно в плане развития стратегий по привлечению новых пользователей.
#
#
# * Напоминаю про моменты, которые уже поясняла в предыдущих комментариях: использование `print` для вывода таблиц.
#
# </div>

# %% [markdown]
# ### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа

# %% [markdown]
# #### 4.2.1. Связь средней выручки с заказа с повторными покупками

# %%
# === 1. Копия профиля ===
profiles = filtered_profile.copy()
# Оставляем только валидные значения выручки
profiles = profiles[
    (profiles['avg_revenue'] > 0) &
    (~profiles['avg_revenue'].isna())
]
# === 2. Деление на группы ===
one_order_users = profiles[profiles['total_orders'] == 1]
returning_users = profiles[profiles['total_orders'] >= 2]

# === 3. Статистика по группам ===
stats_one = one_order_users['avg_revenue'].describe()
stats_returning = returning_users['avg_revenue'].describe()
# Объединяем в один DataFrame
stats_df = pd.DataFrame({
    '1 заказ': stats_one,
    '2+ заказа': stats_returning
}).T  # транспонируем, чтобы группы были строками
# Добавим количество пользователей в отдельный столбец
stats_df['users_count'] = [len(one_order_users), len(returning_users)]
# Выводим
display(stats_df)

# === 3. Настройки визуализации ===
bins = np.arange(0, 3000, 100)  # одинаковые интервалы
alpha = 0.6

plt.figure(figsize=(12, 6))

# === 4. Гистограммы ===
plt.hist(
    one_order_users['avg_revenue'],
    bins=bins,
    density=True,
    alpha=alpha,
    label='1 заказ'
)

plt.hist(
    returning_users['avg_revenue'],
    bins=bins,
    density=True,
    alpha=alpha,
    label='2+ заказа'
)

plt.title('Распределение средней выручки с заказа')
plt.xlabel('Средняя выручка с заказа, руб.')
plt.ylabel('Плотность распределения')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#              count        mean         std   min         25%       50%  \
# 1 заказ     8441.0  552.634692  519.100816  0.07  142.040000  387.9600
# 2+ заказа  13041.0  546.384306  363.943741  0.34  279.248571  500.9475
#
#                   75%          max  users_count
# 1 заказ    839.520000  2628.421739         8441
# 2+ заказа  742.753333  2624.814609        13041

# %% [markdown]
# ***Диапазоны концентрации пользователей***
#
# **Одноразовые покупатели (1 заказ):**
# Основная масса трат сосредоточена между ≈140–840 руб. (от Q1 до Q3).
# Медиана 387,96 руб. показывает «типичный» чек для половины пользователей.
# Есть длинный хвост высоких расходов до 2628 руб., но таких пользователей немного.
#
# **Вернувшиеся покупатели (2+ заказа):**
# Основная концентрация расходов находится между ≈280–743 руб. (Q1–Q3).
# Медиана 500,95 руб. выше, чем у одноразовых, что говорит о более устойчивом среднем уровне выручки.
# Экстремальные значения встречаются реже (максимум 2624 руб.).
#
# **Вывод по диапазонам:**
# Одноразовые покупатели имеют более широкий разброс расходов с большим количеством минимальных и крайне высоких заказов.
# Вернувшиеся пользователи сконцентрированы в среднем диапазоне расходов, более стабильно формируя выручку сервиса.
#
# ***Различия между группами***
#
# **Смещение распределения:**
# Одноразовые — пик распределения ближе к низким расходам (140–390 руб.), длинный хвост к высоким чекам.
# Вернувшиеся — пик распределения смещён к средним расходам (280–500 руб.), хвост менее выражен.
#
# **Вариативность:**
# Одноразовые: стандартное отклонение 519,10 руб. — высокая вариативность.
# Вернувшиеся: стандартное отклонение 363,94 руб. — более стабильные расходы.
#
# **Квартильные различия:**
# Q1 и медиана у вернувшихся почти вдвое выше, чем у одноразовых, что указывает на более высокий базовый уровень расходов.
# Q3 у одноразовых выше, что демонстрирует наличие единичных очень дорогих заказов.
# Средние значения близки (552,63 руб. vs 546,38 руб.), но структура расходов существенно различается: одноразовые покупают либо дешево,
# либо очень дорого, вернувшиеся — стабильно в среднем диапазоне.
#
# **Итог:**
# Одноразовые пользователи: широкий разброс, экстремальные значения, менее предсказуемое поведение.
# Вернувшиеся пользователи: концентрируются в среднем диапазоне, формируют стабильную выручку.
# Различия есть как в распределении, так и в структуре расходов, что важно учитывать при стратегии удержания
# и стимулирования повторных покупок.

# %% [markdown]
# #### 4.2.2. Сравнение распределения по средней выручке с заказа в двух группах пользователей:

# %%
# === 1. Добавляем среднюю выручку на билет ===
filtered_profile = filtered_profile.copy()
filtered_profile['avg_revenue_per_ticket'] = np.where(
    filtered_profile['avg_tickets'] > 0,
    filtered_profile['avg_revenue'] / filtered_profile['avg_tickets'],
    np.nan
)

# %%
# === 2. Формирование групп пользователей ===
group_2_4 = filtered_profile[
    (filtered_profile['total_orders'] >= 2) &
    (filtered_profile['total_orders'] <= 4)
]

group_5_plus = filtered_profile[
    filtered_profile['total_orders'] >= 5
]

# === 3. Средние значения ===
mean_2_4 = group_2_4['avg_revenue_per_ticket'].mean()
mean_5_plus = group_5_plus['avg_revenue_per_ticket'].mean()

print(f'Средняя выручка на билет (2–4 заказа): {mean_2_4:.2f} руб.')
print(f'Средняя выручка на билет (5+ заказов): {mean_5_plus:.2f} руб.')
# Out:
# Средняя выручка на билет (2–4 заказа): 202.43 руб.
# Средняя выручка на билет (5+ заказов): 196.02 руб.

# %%
# === 4. Объединённая статистика для сравнения ===
stats_df = pd.DataFrame({
    '1 заказ': filtered_profile[filtered_profile['total_orders'] == 1]['avg_revenue_per_ticket'].describe(),
    '2–4 заказа': group_2_4['avg_revenue_per_ticket'].describe(),
    '5+ заказов': group_5_plus['avg_revenue_per_ticket'].describe()
}).T

# Добавим столбец с количеством пользователей в каждой группе
stats_df['users_count'] = [
    len(filtered_profile[filtered_profile['total_orders'] == 1]),
    len(group_2_4),
    len(group_5_plus)
]

print('\nСтатистика по группам пользователей (средняя выручка на билет):')
display(stats_df)
# Out:
# Статистика по группам пользователей (средняя выручка на билет):
#              count        mean         std  min         25%         50%  \
# 1 заказ     8544.0  199.722442  167.994006  0.0   56.750000  163.840000
# 2–4 заказа  7219.0  202.433268  140.259670  0.0   85.943333  185.994286
# 5+ заказов  5857.0  196.018643  100.160102  0.0  130.733600  192.016567
#
#                    75%         max  users_count
# 1 заказ     310.261250  1825.65000         8544
# 2–4 заказа  298.759500  1133.48000         7219
# 5+ заказов  253.437833   876.14058         5857

# %%
# === 5. Визуализация ===
bins = np.arange(0, 1000, 50)  # одинаковые интервалы
alpha = 0.6

plt.figure(figsize=(14, 6))

# Гистограммы
plt.subplot(1, 2, 1)
plt.hist(
    filtered_profile[filtered_profile['total_orders'] == 1]['avg_revenue_per_ticket'].dropna(),
    bins=bins, density=True, alpha=alpha, label='1 заказ'
)
plt.hist(
    group_2_4['avg_revenue_per_ticket'].dropna(),
    bins=bins, density=True, alpha=alpha, label='2–4 заказа'
)
plt.hist(
    group_5_plus['avg_revenue_per_ticket'].dropna(),
    bins=bins, density=True, alpha=alpha, label='5+ заказов'
)
plt.title('Распределение средней выручки на билет')
plt.xlabel('Средняя выручка на билет, руб.')
plt.ylabel('Плотность')
plt.legend()
plt.grid(True)

# %% [markdown]
# Наибольшая плотность выручки (самые высокие столбики) у группы «5+ заказов» в диапазоне 200–300 руб.
# эта группа чаще демонстрирует умеренную выручку.
# Группа «1 заказ» имеет пик плотности на более высоких значениях (около 0–200 руб.), но с более длинным «хвостом» в сторону высокой выручки (до 800   руб.), что говорит о большей вариативности.
# Группа «2–4 заказа» занимает промежуточное положение: плотность распределена относительно равномерно в диапазоне 200–400 руб.
# Различия в распределении: группа с высокой активностью («5+ заказов») показывает более узкое и стабильное распределение выручки, тогда как у менее   активных пользователей («1 заказ») наблюдается больший разброс значений.
# Общий тренд: с ростом числа заказов наблюдается смещение распределения к более умеренным значениям выручки и уменьшение разброса.

# %%
# Boxplot
plt.subplot(1, 2, 2)
sns.boxplot(
    data=[
        filtered_profile[filtered_profile['total_orders'] == 1]['avg_revenue_per_ticket'].dropna(),
        group_2_4['avg_revenue_per_ticket'].dropna(),
        group_5_plus['avg_revenue_per_ticket'].dropna()
    ]
)
plt.xticks([0, 1, 2], ['1 заказ', '2–4 заказа', '5+ заказов'])
plt.ylabel('Средняя выручка на билет, руб.')
plt.title('Boxplot средней выручки на билет')

plt.tight_layout()
plt.show()

# %% [markdown]
# ***Вывод***
#
# Средняя выручка на билет у пользователей с **2–4 заказами** составляет **202,43 руб.**, у пользователей с **5+ заказами** — **196,02 руб.**
# Пользователи с 2–4 заказами в среднем приносят немного больше выручки на один билет (разница около 6 руб.).
#
# При этом пользователи с 5+ заказами демонстрируют более стабильное поведение, тогда как у группы 2–4 заказов наблюдается больший разброс значений.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ взаимосвязи средней выручки и числа заказов <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
#
# <b>Отлично ✅:</b> Плюсик за грамотное оформление графиков - заголовок, подписи осей, легенда, поправка на размер выборки (`density`).
# </div>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b>  Почему-то в первой части анализируется выручка с одного билета, а во втором случае уже выручка с заказа (к тому же из неотфильтрованных профилей), непорядок. Если ты будешь работать с выручкой с билета, то пользователей стоит также брать только тех, кого мы допустили в таблицу с отфильтрованными профилями, чтобы не учитывать сведения о перекупах.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Здорово, что в первой части нормализуешь размер бинов - так удобно сопоставлять доли пользователей по диапазонам цен. То же самое стоит сделать и во втором случае.
#
#
# * Важно иметь в виду, что среднее значение довольно сильно зависит от характера распределения, если есть какие-то сильные выбросы, они могут утянуть среднее значение вверх, хотя основаня масса значений будет гораздо ниже. Поэтому здесь важно сравнивать именно распределения, выделить сегменты концентрации, обратить внимание на хвосты.
#
#
# * В выводах было бы не лишним попробовать подумать, что для нас могут значить данные результаты, почему они могли получиться именно такими, что это говорит о клиентах?
#
#
# </div>

# %% [markdown]
#  #### 4.2.3. Влияние среднего количества билетов в заказе на повторные покупки

# %%
# 1. Создаём категорию по среднему количеству билетов в заказе (avg_tickets)
filtered_profile['ticket_group'] = pd.cut(
    filtered_profile['avg_tickets'],  # исправлено название столбца
    bins=[1, 2, 3, 5, float('inf')],  # интервалы: [1,2), [2,3), [3,5), [5,∞)
    labels=['1-2 билета', '2-3 билета', '3-5 билетов', '5+ билетов'],
    right=False  # правая граница не включается в интервал
)

# %%
# 2. Считаем общее число пользователей в каждом сегменте
user_count_by_group = filtered_profile['ticket_group'].value_counts().sort_index()
print("Общее число пользователей по сегментам:")
display(user_count_by_group)

# 3. Определяем признак повторной покупки (используем is_two как признак повторной покупки)
filtered_profile['is_repeat'] = filtered_profile['is_two'].astype(int)

# 4. Группируем по сегментам и считаем долю повторных покупок
repeat_stats = filtered_profile.groupby('ticket_group')['is_repeat'].agg([
    ('total_users', 'count'),  # общее число пользователей в сегменте
    ('repeat_users', 'sum'),   # число пользователей с повторными покупками
    ('repeat_rate', 'mean')    # доля повторных покупок
]).round(3)

print("\nСтатистика по сегментам (доля повторных покупок):")
display(repeat_stats)

# 5. Анализируем распределение по сегментам
total_users = repeat_stats['total_users'].sum()
repeat_stats['user_share'] = (repeat_stats['total_users'] / total_users * 100).round(1)
print("\nРаспределение пользователей по сегментам (в % от общего числа):")
display(repeat_stats[['user_share']])
# Out:
# Общее число пользователей по сегментам:
# ticket_group
# 1-2 билета     2367
# 2-3 билета     9500
# 3-5 билетов    9090
# 5+ билетов      663
# Name: count, dtype: int64
# Статистика по сегментам (доля повторных покупок):
# C:\Users\Виталий\AppData\Local\Temp\ipykernel_15796\4283070202.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   repeat_stats = filtered_profile.groupby('ticket_group')['is_repeat'].agg([
#               total_users  repeat_users  repeat_rate
# ticket_group
# 1-2 билета           2367          1161        0.490
# 2-3 билета           9500          6940        0.731
# 3-5 билетов          9090          4853        0.534
# 5+ билетов            663           122        0.184
# Распределение пользователей по сегментам (в % от общего числа):
#               user_share
# ...

# %%
# Визуализация
plt.figure(figsize=(10, 6))
sns.countplot(data=profile, x='ticket_group', color='darkcyan')
plt.title('Распределение пользователей по сегментам')
plt.xlabel('Сегмент по среднему количеству билетов')
plt.ylabel('Число пользователей')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(data=repeat_stats.reset_index(), x='ticket_group', y='repeat_rate', color='darkcyan')
plt.title('Доля повторных покупок по сегментам')
plt.xlabel('Сегмент по среднему количеству билетов')
plt.ylabel('Доля повторных покупок')
plt.show()

# %% [markdown]
# ***Выводы по сегментации пользователей по среднему числу билетов в заказе***
#
# **Распределение пользователей**
# Распределение пользователей по сегментам не является равномерным и имеет выраженную концентрацию:
#
# - Сегмент **«2–3 билета»** — крупнейший, **43,9% пользователей (9 500 человек)**.
# - Сегмент **«3–5 билетов»** — второй по численности, **42,0% пользователей (9 090 человек)**.
# - Сегмент **«1–2 билета»** — значительно меньше, **10,9% пользователей (2 367 человек)**.
# - Сегмент **«5+ билетов»** — наименее многочисленный, **3,1% пользователей (663 человека)**.
#
# Таким образом, около **86% всей аудитории сосредоточено в сегментах «2–3 билета» и «3–5 билетов»**, что говорит о преобладании групповых или парных покупок и подтверждает сконцентрированное распределение пользователей.
#
# ---
# ***Доля повторных покупок и интерпретация сегментов***
# Между сегментами наблюдаются заметные различия в доле повторных покупок:
#
# - **«2–3 билета» — 73,1% повторных покупок**
#   Это самый лояльный сегмент. Вероятно, его формируют пользователи, которые регулярно посещают мероприятия вдвоём или небольшой компанией (пары, друзья). Формат покупки удобен, чек умеренный, а опыт использования сервиса — стабильный, что способствует возвращаемости.
#
# - **«3–5 билетов» — 53,4% повторных покупок**
#   Сегмент со средней лояльностью. Можно предположить, что сюда входят компании друзей или семьи, посещающие мероприятия нерегулярно. Решение о покупке требует большего согласования, что снижает частоту повторных заказов.
#
# - **«1–2 билета» — 49,0% повторных покупок**
#   Вероятно, это одиночные пользователи или случайные покупатели. Их поведение менее устойчиво: часть возвращается, но значительная доля делает разовую покупку.
#
# - **«5+ билетов» — 18,4% повторных покупок**
#   Самая низкая возвращаемость. Этот сегмент, скорее всего, состоит из разовых крупных заказов (корпоративные покупки, организаторы, разовые мероприятия). Низкая доля повторных покупок здесь выглядит ожидаемой и не обязательно является проблемой продукта.
#
# ---
#
# ***Итоговые выводы***
#
# - Наиболее ценный с точки зрения лояльности сегмент — **пользователи, покупающие 2–3 билета**: они составляют крупнейшую долю аудитории и чаще всего возвращаются.
# - Сегменты **1–2 билета** и **3–5 билетов** демонстрируют средний уровень возвращаемости и могут быть точками роста за счёт стимулирования повторных покупок.
# - Сегмент **5+ билетов** имеет низкую долю повторных заказов, что, вероятно, связано с природой самих покупок, а не с качеством сервиса.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ взаимосвязи количества билетов в заказе и возвращаемости <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
#
# <b>Отлично ✅:</b> Здорово, что используешь удобный метод [сut](https://pandas.pydata.org/docs/reference/api/pandas.cut.html) и верно настраиваешь включение/исключение границ.
# </div>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> Здесь снова задействованы неотфильтрованные профили.
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b>
#
# * Чтобы не перегружать графики лишним, в них стоит вводить только элементы с информационной содержательностью. Сейчас расцветка нам ничего полезного не рассказывает.
#
#
# * В выводах было бы неплохо предположить, что это за группы у нас сформировались (что за типы клиентов), и почему получились именно такие результаты по возвращаемости. Опять же, это может быть полезно в плане развития стратегий по привлечению новых пользователей.
#
# </div>

# %% [markdown]
# ### 4.3.Исследование временных характеристик первого заказа

# %% [markdown]
# #### 4.3.1. Влияние дня недели первой покупки на возврат пользователей

# %%
# Создаём столбец с днём недели (0 — понедельник, 6 — воскресенье)
filtered_profile['first_order_day_of_week'] = filtered_profile['first_order_date'].dt.dayofweek

# Можно добавить читаемые названия дней недели
day_names = {0: 'Понедельник', 1: 'Вторник', 2: 'Среда', 3: 'Четверг', 4: 'Пятница', 5: 'Суббота', 6: 'Воскресенье'}
filtered_profile['first_order_day_name'] = filtered_profile['first_order_day_of_week'].map(day_names)

# %%
user_count_by_day = filtered_profile.groupby('first_order_day_name').size()
print("Общее число пользователей по дням недели:")
display(user_count_by_day)
# Out:
# Общее число пользователей по дням недели:
# first_order_day_name
# Воскресенье    2775
# Вторник        3176
# Понедельник    2917
# Пятница        3256
# Среда          3063
# Суббота        3321
# Четверг        3112
# dtype: int64

# %%
repeat_stats_by_day = filtered_profile.groupby('first_order_day_name')['is_two'].agg([
    ('total_users', 'count'),  # общее число пользователей
    ('repeat_users', 'sum'),   # число пользователей с повторными покупками
    ('repeat_rate', 'mean')    # доля повторных покупок
]).round(3)

print("Статистика по дням недели (доля повторных покупок):")
display(repeat_stats_by_day)
# Out:
# Статистика по дням недели (доля повторных покупок):
#                       total_users  repeat_users  repeat_rate
# first_order_day_name
# Воскресенье                  2775          1645        0.593
# Вторник                      3176          1936        0.610
# Понедельник                  2917          1812        0.621
# Пятница                      3256          1920        0.590
# Среда                        3063          1885        0.615
# Суббота                      3321          2061        0.621
# Четверг                      3112          1817        0.584

# %%
day_order = [
    'Понедельник',
    'Вторник',
    'Среда',
    'Четверг',
    'Пятница',
    'Суббота',
    'Воскресенье'
]
plt.figure(figsize=(10, 6))

sns.barplot(
    data=user_count_by_day.reset_index(),
    x='first_order_day_name',
    y=0,
    order=day_order
)

plt.title('Количество пользователей по дню недели первой покупки')
plt.xlabel('День недели')
plt.ylabel('Число пользователей')
plt.show()

# %%
overall_repeat_rate = filtered_profile['is_two'].mean()
overall_repeat_rate
plt.figure(figsize=(10, 6))

sns.barplot(
    data=repeat_stats_by_day.reset_index(),
    x='first_order_day_name',
    y='repeat_rate',
    order=day_order
)

# линия общей возвращаемости
plt.axhline(
    y=overall_repeat_rate,
    linestyle='--',
    linewidth=2,
    label=f'Общая возвращаемость: {overall_repeat_rate:.1%}'
)

plt.title('Доля повторных покупок по дню недели первой покупки')
plt.xlabel('День недели')
plt.ylabel('Доля повторных покупок')
plt.legend()
plt.show()

# %% [markdown]
# ***Выводы по дню недели первой покупки***
#
# Распределение пользователей по дням недели первой покупки в целом равномерное. Незначительно выделяются:
# - **суббота** — наибольшее число пользователей (3 321),
# - **воскресенье** — наименьшее (2 775).
#
# Доля повторных покупок варьируется в узком диапазоне **58,4–62,1%**, что указывает на **слабое влияние дня недели на лояльность**.
#
# Относительными лидерами по возвращаемости являются **понедельник и суббота** (по 62,1%),
# а наименьшие значения наблюдаются в **четверг, пятницу и воскресенье**.
# Разница между максимумом и минимумом составляет около **3,5 п.п.** и не является критичной.
#
# Вероятно, более высокая возвращаемость в понедельник и субботу связана с более осознанными покупками и планированием досуга,
# тогда как покупки в четверг–пятницу и воскресенье чаще носят спонтанный характер.
#
# **Итог:** день недели первой покупки оказывает ограниченное влияние на возвращаемость пользователей и не может рассматриваться
# как самостоятельный фактор для построения стратегии удержания. Для более точных выводов необходимо учитывать дополнительные
# параметры: тип мероприятий, сезонность, время покупки и пользовательские сегменты.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ возвращаемости по дням недели  <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Различия по дням недели, действительно, наблюдаются, хотя и не очень заметные. Чтобы судить более однозначно, было бы неплохо сопроводить сравнение оценкой статистической значимости. Это будет изучаться далее на курсе.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> И здесь неотфильтрованные профили.
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b>
#
# * Столбики на графике стоит расположить в логическом порядке.
#
#
# * Для удобства на график можно добавить линию общей возвращаемости.
#
#
# * Как будто бы выводы сейчас не совсем соответствуют графику.
#
#
# * В выводах было бы неплохо также предположить, почему в топ и антитоп (которые все-таки создается, хотя и на так явно) выбиваются определенные дни недели? Какие суждения относительно этого можно выстроить?
#
#
# </div>

# %% [markdown]
#  #### 4.3.2. Влияние среднего интервала между заказами на удержание клиентов

# %%
# 1) Формируем группы
group_2_4 = filtered_profile[(filtered_profile['is_two'] == True) & (filtered_profile['is_five'] == False)]
group_5_plus = filtered_profile[filtered_profile['is_five'] == True]

# 2) Берём по одному значению на пользователя
intervals_2_4 = group_2_4['avg_time_between_orders'].dropna()
intervals_5_plus = group_5_plus['avg_time_between_orders'].dropna()

# 3) Статистика (по пользователям)
def describe_series(s):
    return pd.Series({
        'users': s.shape[0],
        'mean': s.mean(),
        'median': s.median(),
        'std': s.std()
    })

stats = pd.DataFrame({
    '2–4 заказа': describe_series(intervals_2_4),
    '5+ заказов': describe_series(intervals_5_plus)
}).T.round(2)

display(stats)
# Out:
#              users   mean  median    std
# 2–4 заказа  7219.0  21.69   10.00  28.57
# 5+ заказов  5857.0  10.16    8.44   7.83

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

sns.histplot(intervals_2_4, bins=30, stat='density', ax=axes[0])
axes[0].set_title('2–4 заказа')
axes[0].set_xlabel('Среднее время между заказами, дни')
axes[0].set_ylabel('Плотность')

sns.histplot(intervals_5_plus, bins=30, stat='density', ax=axes[1])
axes[1].set_title('5+ заказов')
axes[1].set_xlabel('Среднее время между заказами, дни')

plt.tight_layout()
plt.show()

# %% [markdown]
# ***Вывод по времени между заказами***
#
# Пользователи с **5+ заказами** возвращаются быстрее и стабильнее (медиана — **8,4 дня**), что указывает на сформированную привычку повторных покупок.
# У пользователей с **2–4 заказами** интервалы между заказами больше и менее предсказуемы (медиана — **10 дней**, длинный хвост распределения).
#
# ***Практическая интерпретация***
#
# Время с момента последнего заказа можно использовать как триггер удержания:
# - для сегмента **5+ заказов** — при отсутствии активности **более 12–15 дней**;
# - для сегмента **2–4 заказов** — при отсутствии активности **более 20–25 дней**.
#
# Превышение этих порогов снижает вероятность самостоятельного возврата и оправдывает запуск вовлекающих механик.
#
# ***Возможные меры для возвращения клиента***
# Интервал времени с момента последнего заказа можно использовать как триггер возвращаемости: при превышении характерного для сегмента порога вероятность самостоятельного возврата резко снижается, и становится целесообразным подключение вовлекающих механик.
# Определяем «ожидаемое окно возврата»
#
# 🟢 Зелёная зона — высокая вероятность самостоятельного возврата
# 5+ заказов: до 10–12 дней
# 2–4 заказа: до 12–15 дней
# ➡️ Пользователя не трогаем: он с высокой вероятностью вернётся сам.
#
# 🟡 Жёлтая зона — неопределённость
# 5+ заказов: 12–18 дней
# 2–4 заказа: 15–25 дней
# ➡️ Вероятность возврата падает, но ещё есть.
# Здесь уместны мягкие триггеры:
# рекомендации мероприятий,
# напоминания,
# персональные подборки без скидок.
#
# 🔴 Красная зона — высокий риск потери
# 5+ заказов: >18–20 дней
# 2–4 заказа: >25–30 дней
# ➡️ Самостоятельный возврат маловероятен.
# Нужно подключать активные стратегии удержания:
# скидки,
# промокоды,
# push/email с ограничением по времени.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ возвращаемости по количеству дней между заказами <a class="tocSkip"></h4>
#
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b>
#
# * Здесь тоже профили неотфильтрованные.
#
#
# * Сейчас здесь происходит что-то странное. Пока не совсем понимаю, зачем ты распространяешь усредненное время на количество заказов. Среднее уже содержит информацию о всех заказах пользователей, таким образом мы не узнаем характеристику поведения пользователей во времени в зависимости от их сегмента (по количеству заказов). Здесь нам необходимо взять среднее время из отфильтрованных профилей, и построить две гистограммы, как мы делали с выручкой. График строим не примерный через барплоты, а фактическое распределение.
#
#
# * Разве признак с временем у тебя был рассчитан в днях? У нас данные только за полгода, таких количеств дней не может быть.
#
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b> Выводы сейчас строятся достаточно банально. Логично, что на ограниченном промежутке времени у клиента с большим количеством заказов интервалы будут меньше. Поэтому здесь стоит делать обратный ход - подумать, как по интервалу времени после очередного заказа можно определять, есть ли шанс, что клиент еще вернется самостоятельно, или пора подключать стратегии для вовлечения в новый заказ.
#
# </div>

# %% [markdown]
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя

# %%
df_cor = filtered_profile.copy()

# --- 1) целевой сегмент активности ---
def order_segment(x):
    if x == 1:
        return '1_order'
    elif 2 <= x <= 4:
        return '2_4_orders'
    else:
        return '5_plus_orders'

df_cor['order_segment'] = df_cor['total_orders'].apply(order_segment).astype('category')

# --- 2) выкидываем то, что не должно участвовать ---
drop_cols = []

# идентификатор
if 'user_id' in df_cor.columns:
    drop_cols.append('user_id')

# производные бинарные
for c in ['is_two', 'is_five', 'is_repeat']:
    if c in df_cor.columns:
        drop_cols.append(c)

# исходный total_orders лучше убрать из матрицы,
# чтобы не получить тривиальную связь "segment ~ total_orders"
if 'total_orders' in df_cor.columns:
    drop_cols.append('total_orders')

df_cor = df_cor.drop(columns=drop_cols)

interval_cols = [c for c in [
    'avg_revenue',
    'avg_tickets',
    'avg_days_between_orders',
    'avg_revenue_per_ticket',
    'avg_time_between_orders'
] if c in df_cor.columns]

# приводим интервальные к числам (убираем object)
for c in interval_cols:
    df_cor[c] = pd.to_numeric(df_cor[c], errors='coerce')

datetime_cols = df_cor.select_dtypes(include=['datetime64[ns]', 'datetime64[ns, UTC]']).columns.tolist()
if datetime_cols:
    df_cor = df_cor.drop(columns=datetime_cols)

# --- 5) phi_k матрица ---
phik_corr = df_cor.phik_matrix(interval_cols=interval_cols)

# --- 6) корреляции факторов с сегментом активности ---
corr_to_segment = phik_corr[['order_segment']].drop(index=['order_segment']).sort_values(
    by='order_segment', ascending=False
)

# --- 7) heatmap (0..1, белый в 0) ---
plt.figure(figsize=(6, max(8, 0.35 * len(corr_to_segment))))
sns.heatmap(
    corr_to_segment,
    annot=True,
    vmin=0, vmax=1,
    cmap='Reds'
)
plt.title('Phi_k: связь признаков с сегментом активности (order_segment)')
plt.show()

# %% [markdown]
# ***Вывод***
#
# Анализ коэффициента phi_k показал, что наибольшая связь с количеством заказов пользователя наблюдается у поведенческих и экономических характеристик,   а не у признаков первого контакта.
#
# **Наиболее связанными с числом заказов являются:**
#
# среднее время между заказами (avg_days_between_orders),
# среднее количество билетов в заказе (avg_tickets),
# средняя выручка с заказа (avg_revenue),
# средняя выручка за билет (avg_revenue_per_ticket).
#
# Значения phi_k для этих признаков находятся на уровне умеренной статистической связи, что указывает на их значимую роль в различии пользователей по уровню активности.
#
# Признаки первого заказа и канала привлечения
# (first_device, first_region, first_ticket_partner, first_event_type, день недели первого заказа) демонстрируют слабую или близкую к нулю связь с   количеством заказов. Это говорит о том, что характеристики первого контакта дают ограниченную информацию о будущей активности пользователя.
#
# Таким образом, активность пользователя в большей степени определяется его последующим поведением, а не параметрами первого заказа или источником привлечения.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ корреляции <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b>
#
# * Здесь тоже неотфильтрованные профили.
#
#
# * Обрати внимание, что сейчас мы исследуем влияние факторов на то, насколько активным окажется пользователь (с точки зрения количества заказов), поэтому сегментация количества заказов нам нужна была для того, чтобы сделать интервалы более сбалансированными по составу в противовес тому биннингу, который происходит автоматически в алгоритме Phik, когда мы передаем ему количественный признак. Отсюда следует, что корреляцию нужно проверять не внутри сегментов между факторами, а факторов с самими сегментами.
#
#
# * Не совсем понимаю, откуда взяты значения в выводе.
#
#
# * Phik корреляция всегда имеет положительные значения. Данная корреляция не говорит о направленности взаимосвязи, только о ее силе. Поэтому некорректно строить суждения, что чем больше что-то одно, тем больше/меньше что-то другое. О направленности мы можем лишь предполагать, полагаясь на логику и здравый смысл, либо же подкреплять суждения результатами предыдущих шагов. Если ты хочешь добавить про направленность, то важно оставить пояснение, на основе чего мы это говорим.
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * В анализ сейчас включены лишние признаки. В бинарных признаках `is_two` и `is_five` (и еще `is_repeat`) смысла нет, они основаны на количестве заказов и не несут сейчас ничего интересного. Аналогично с сегментами по количеству билетов и с днем недели в двух форматах, нужно что-то одно, чтобы не создавить информационную избыточность за счет идентичного содержания.
#
#     А чтобы искать взаимосвязи с датами, нужно дробить их на отдельные составляющие, которые варьируются в данных (год, месяц, день недели, час, все категориальные, кроме года). Однако обрати внимание, что мы сейчас изучаем корреляцию с количеством заказов, но количество заказов, которые он успел сделать, непременно будет зависеть от того, насколько близко к концу охваченного нами периода он присоединился. Такая оценка не расскажет нам ничего интересного. Чтобы изучать, насколько сильно варьируется качество привлеченных клиентов (с точки зрения количества их последующих заказов) в зависимости от времени, необходимо фиксировать период обзора с момента их присоединения, чтобы все клиенты были в равных условиях при оценке.
#
#
# * Расцветку для тепловой карты имеет смысл выбирать трехцветную, если диапазон возможных значений от -1 до 1 (например, синий, белый, красный, белый при этом в нуле), и двухцветную, если от 0 до 1 (в 0 - белый, в 1 - красный). Поскольку на 0 будет нейтральный цвет, величину корреляции можно будет воспринимать через интенсивность цвета, а по самому цвету - положительная она или отрицательная. Phik корреляция имеет только положительные значения.
#
#
# * В выводах было бы неплохо провести параллель с нашими предыдущими шагами анализа. Прокомментировать, почему высокая корреляция получается с одними признаками и низкая с другими. Что по итогу важно для манипулирования возвращаемостью клиентов, а что нет?
#
# </div>

# %% [markdown]
# ### 5. Выводы и рекомендации
#
# #### Выводы
#
# В ходе проекта был проведён исследовательский анализ данных о заказах пользователей сервиса Яндекс Афиша с целью выявить факторы, связанные с возвратом пользователей и количеством повторных покупок.
#
# В анализе использовались данные о 268 202 заказах за период с июня по октябрь 2024 года (после очистки: удаление отрицательной выручки, неполных дубликатов и фильтрация выбросов по выручке). Итоговая пользовательская выборка после формирования профилей и отсечения 1% пользователей с аномально высоким числом заказов составила 21 620 пользователей.
#
# Анализ показал, что поведение пользователей неоднородно. Распределение по числу заказов выраженно асимметрично: медианное значение — 2 заказа, при этом доля пользователей с 2+ заказами — 60,48%, а доля пользователей с 5+ заказами — 27,09%. При этом 75% пользователей совершают не более 5 заказов, а «длинный хвост» формируется относительно небольшой группой более активных покупателей.
#
# Средняя выручка с заказа (по очищенной выборке профилей) составляет 527,41 руб. В среднем пользователи покупают 2,74 билета за заказ (медианное значение около 2,75), что отражает преобладание покупок на 2–3 билета.
#
# Связь состава заказа с повторными покупками проявляется сильнее, чем «размер» разового заказа. Наиболее лояльным оказался сегмент пользователей со средним размером заказа 2–3 билета: доля повторных покупок в нём достигает 73,1% (и это самый массовый сегмент — 43,9% пользователей). Напротив, крупные покупки 5+ билетов не означают высокую лояльность: возвращаемость в этом сегменте составляет лишь 18,4% (доля сегмента — 3,1%), что похоже на разовые групповые/корпоративные сценарии.
#
# Временные характеристики подтверждают, что регулярность — ключ к высокой активности. Пользователи с 5+ заказами возвращаются заметно быстрее и стабильнее: медианный средний интервал между заказами — 8,44 дня (среднее — 10,16), тогда как у пользователей с 2–4 заказами медиана выше — 10 дней (среднее — 21,69, с более «длинным хвостом» редких возвращений). То есть «частые» пользователи отличаются прежде всего меньшими паузами между покупками.
#
# Таким образом, решающую роль в удержании играет не величина разового заказа, а паттерн регулярных покупок и сценарий использования (типичный «пара/небольшая компания» 2–3 билета даёт максимальную повторяемость). Практически это означает, что фокус удержания логичнее строить вокруг пользователей со средним размером заказа и контроля «окна возврата» по времени после последней покупки, а крупные заказы рассматривать как отдельный (часто разовый) сегмент.
#
# #### Рекомендации
#
# 1. **Сокращать интервал между первым и вторым заказом** — использовать триггерные рассылки и push-уведомления в течение 7–14 дней после первой покупки.
# 2. **Сфокусироваться на сегменте пользователей с 2–3 билетами в заказе** как наиболее массовом и лояльном.
# 3. **Развивать успешные точки входа**: категории мероприятий (театры и выставки), устройства и партнёрские каналы, показавшие более высокую возвращаемость.
# 4. **Разработать отдельную стратегию для крупных заказов (5+ билетов)**, так как данный сегмент характеризуется низкой повторной активностью.
# 5. **Работать над увеличением среднего чека** через апселл и персональные предложения, не увеличивая при этом интервалы между заказами.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Итоговые выводы <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> С задачей в целом справились! Ключевые моменты отражены, что позволяет быстро ознакомиться с процессом работы и результатом, не вдаваясь в технические детали. Здорово, что завершаешь проект рекомендациями, основанные на выявленных закономерностях. Предложенные рекомендации логично следуют из анализа и могут быть непосредственно реализованы в маркетинговых стратегиях подогревания и удержания.
#
# </div>
#
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> Здесь тоже необходимо скорректировать выводы в отношении корреляции.
#
# </div>

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Публикация в Git <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
#
# <b>Нужно доработать ❌:</b> Не увидела ссылки на репозиторий. Напоминаю, что в публичном доступе не должны оказаться ключи подключения к БД (ни `.env`, ни в тетрадке), а также нам нужны `.gitignore` (в которым мы как раз указываем, чтобы он игнорировал файлы с ключами) и `requirements.txt` (чтобы зафиксировать версии библиотек, которые были использованы, и твой код гарантированно у всех воспроизводился).
#
# </div>
#
# <div style="border-radius: 10px" class="alert alert-warning">
#
# <b>Рекомендации💡:</b> Можно заполнить `readme` полезной информацией о проекте, зафиксировать цели, указать ключевые моменты и полученные выводы.
#
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; border-radius: 10px;  padding: 40px">
# <h3>Общий вывод по проекту <a class="tocSkip"></h3>
#
# Виталий, спасибо за твой проект! У тебя неплохая работа, основа есть, однако есть еще достаточно много моментов, которые требуют твоего внимания. Кратко пройдусь по впечатлениям.
#
# **Полнота:** <span style="color:Red;">не хватает публикации в Git. Не забываем про засекречивание ключей.</span>
#
# **Корректность:**
#
# * <span style="color:Red;">Заполнение пропусков в количестве дней между заказами в данном проекте нам не доступно. Любое значение будет искажать статистические показатели.</span>
# * <span style="color:Red;">Необходимо расширить предобработку данных. Проверка на наличие полных и неполных дубликатов, и в принципе корректности всех показателей, которые задействуются в дальнейшем при анализе (говорю про количество дней) - одни из важных этапов предобработки по умолчанию.</span>
# * <span style="color:Red;">Каждый раздел необходимо завершать резюмирующими выводами.</span>
# * <span style="color:Red;">Необходимо скорректировать создание профилей, упорядочить заказы по времени, чтобы корректно отбирать характеристики первого заказа.</span>
# * <span style="color:Red;">Для анализа необходимо использовать таблицу с отфильтрованными профилями, чтобы выбросы не искажали статистические показатели.</span>
# * <span style="color:Red;">Необходимо пересмотреть выводы в отношении гипотезы по сегментам, сформированным первыми заказами.</span>
# * <span style="color:Red;">В отношении выручки необходимо определиться, что мы анализируем, выручку с заказа или с билета.</span>
# * <span style="color:Red;">Необходимо скорректировать анализ количества дней между заказами, сейчас там происходят странные вещи.</span>
# * <span style="color:Red;">Необходимо пересмотреть оценку и интерпретацию корреляции.</span>
#
# **Аналитическая проницательность:** здесь мне сложно сказать что-то однозначное, поскольку явно видны следы ИИ. Могу лишь порекомендовать ознакомиться с [этой статьей](https://habr.com/ru/companies/yandex_praktikum/articles/944998/).
#
# **Эффективность кода:** по этому критерию в целом окей, но в некоторых местах можно использовать чуть более удобные и компактные методы, зафункционалить повторяющиеся действия.
#
# **Оформление:** им тоже важно не пренебрегать! Оформление тесно связано с удобством восприятия предоставляемой информации и созданием впечатления о работе. Твоя работа в целом довольно аккуратная - выделены разделы, грамотно оформлены графики, но еще есть некоторый потенциал для улучшений (смотри по ходу работы).
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
# <img src="https://99px.ru/sstorage/86/2015/12/image_86271215043043632690.gif" />
